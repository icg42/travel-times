# %% [markdown]
# ## Thanksgiving assignment (15 points)
#
# You have been given the dataset `travel-times` in a CSV format. This dataset comes from a driver that uses an app to track GPS coordinates as he drives to work and back each day. The app collects the location and elevation data. In total, data for about 200 trips are summarized in this data set.
#
# Load the `travel-times` in a `df` variable using `pandas` and then perform the following:
# - print the shape of the dataset **(1 points)**
# - print the first 15 rows of the dataset **(1 points)**
# - get information for the features (columns) with missing values **(1 points)**
# - drop duplicate values (if any) by keeping only the last instance **(1 points)**
# - calculate the total number of missing values (if any) on each column **(2 points)**
# - create two copies of the dataframe, and then:
#     - drop rows with missing values from the 1st copy **(1 points)**
#     - drop columns with missing values from the 2nd copy **(1 points)**
# - get summary statistics and see the correlation between the numerical columns **(1 points)**
# - show rows 11 to 14 **(1 points)**
# - create a subset with trips occurred on November 23, 2011 and January 6, 2012 **(2 points)**
# - produce a scatterplot between `Distance` and `TotalTime` **(1 points)**
#     * Use:
# ```python
# import matplotlib.pyplot as plt
# plt.rcParams.update({'font.size': 20, 'figure.figsize': (10, 8)})
# ```
# - produce boxplots for `AvgSpeed` and `AvgMovingSpeed` (use different cells for each) **(2 points)**

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.rcParams.update({'font.size': 20, 'figure.figsize': (10, 8)})

url = 'travel-times.csv'
df = pd.read_csv(url)

print('Printing the shape of the dataset:')
shape = df.shape
print(shape, "\n")

print('Printing the first 15 rows of the dataset:')
print(df.head(15), "\n")

print('Getting information for the features (columns) with missing values:')
df.info()
print('\n')

print('Dropping duplicate values (if any) by keeping only the last instance:')
df.drop_duplicates(inplace=True, keep='last')
print(shape, "\n")

print('Calculating the total number of missing values (if any) on each column:')
print(df.isnull().sum(), "\n")

print('Dropping rows with missing values from the 1st copy:')
row_df = df.copy()
print(row_df.dropna(), '\n')

print('Dropping columns with missing values from the 2nd copy:')
column_df = df.copy()
print(column_df.dropna(axis=1),'\n')

print('Getting summary statistics:')
print(df.describe(),'\n')

print('Viewing the correlation between the numerical columns:')
print(df.corr(),'\n')

print('Showing rows 11 to 14:')
print(df.iloc[11:15],'\n')

print('Creating a subset with trips occurred on November 23, 2011 and January 6, 2012:')
print(df[(df['Date'] == '11/23/2011') | (df['Date'] == '1/6/2012')], '\n')

print('Producing plots for dataset:')
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20, 'figure.figsize': (10, 8)})

df.plot(kind='scatter', x='TotalTime', y='Distance', title='Total Time vs. Distance')

fig, axes = plt.subplots(nrows=1, ncols=1)
df['AvgSpeed'].plot(kind='box', title='Average Speed')

fig, axes = plt.subplots(nrows=1, ncols=1)
df['AvgMovingSpeed'].plot(kind='box', title='Average Moving Speed')
# Out:
# Printing the shape of the dataset:
# (205, 13)
#
# Printing the first 15 rows of the dataset:
#           Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0     1/6/2012     16:37     Friday    Home     51.29     127.4      78.3
# 1     1/6/2012     08:20     Friday     GSK     51.63     130.3      81.8
# 2     1/4/2012     16:17  Wednesday    Home     51.27     127.4      82.0
# 3     1/4/2012     07:53  Wednesday     GSK     49.17     132.3      74.2
# 4     1/3/2012     18:57    Tuesday    Home     51.15     136.2      83.4
# 5     1/3/2012     07:57    Tuesday     GSK     51.80     135.8      84.5
# 6     1/2/2012     17:31     Monday    Home     51.37     123.2      82.9
# 7     1/2/2012     07:34     Monday     GSK     49.01     128.3      77.5
# 8   12/23/2011     08:01     Friday     GSK     52.91     130.3      80.9
# 9   12/22/2011     17:19   Thursday    Home     51.17     122.3      70.6
# 10  12/22/2011     08:16   Thursday     GSK     49.15     129.4      74.0
# 11  12/21/2011     07:45  Wednesday     GSK     51.77     124.8      71.7
# 12  12/20/2011     16:05    Tuesday    Home     51.45     130.1      75.2
# 13  12/20/2011     06:04    Tuesday     GSK     49.01     119.0      77.4
# 14  12/19/2011     16:18     Monday    Home     51.04     132.2      77.5
#
#     AvgMovingSpeed FuelEconomy  TotalTime  MovingTime Take407All Comments
# 0             84.8         NaN       39.3        36.3         No      NaN
# 1             88.9         NaN       37.9        34.9         No      NaN
# 2             85.8         NaN       37.5        35.9         No      NaN
# 3             82.9         NaN       39.8        35.6         No      NaN
# 4             88.1         NaN       36.8        34.8         No      NaN
# 5             88.8         NaN       36.8        35.0         No      NaN
# 6             87.3           -       37.2        35.3         No      NaN
# 7             85.9           -       37.9        34.3         No      NaN
# 8             88.3        8.89       39.3        36.0         No      NaN
# 9             78.1        8.89       43.5        39.3         No      NaN
# 10            81.4        8.89       39.8        36.2         No      NaN
# 11            78.9        8.89       43.3        39.4         No      NaN
# 12            82.7        8.89       41.1        37.3         No      NaN
# 13            82.0        8.89       38.0        35.9         No      NaN
# 14            83.5        8.89       39.5        36.7         No      NaN
#
# Getting information for the features (columns) with missing values:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            205 non-null    object
#  1   StartTime       205 non-null    object
#  2   DayOfWeek       205 non-null    object
#  3   GoingTo         205 non-null    object
#  4   Distance        205 non-null    float64
#  5   MaxSpeed        205 non-null    float64
#  6   AvgSpeed        205 non-null    float64
#  7   AvgMovingSpeed  205 non-null    float64
#  8   FuelEconomy     188 non-null    object
#  9   TotalTime       205 non-null    float64
#  10  MovingTime      205 non-null    float64
#  11  Take407All      205 non-null    object
#  12  Comments        24 non-null     object
# dtypes: float64(6), object(7)
# memory usage: 20.9+ KB
#
#
# Dropping duplicate values (if any) by keeping only the last instance:
# (205, 13)
#
# Calculating the total number of missing values (if any) on each column:
# Date                0
# StartTime           0
# DayOfWeek           0
# GoingTo             0
# Distance            0
# MaxSpeed            0
# AvgSpeed            0
# AvgMovingSpeed      0
# FuelEconomy        17
# TotalTime           0
# MovingTime          0
# Take407All          0
# Comments          181
# dtype: int64
#
# Dropping rows with missing values from the 1st copy:
#            Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 15   12/19/2011     07:34     Monday     GSK     52.00     137.8      76.5
# 49   11/21/2011     07:24     Monday     GSK     52.25     127.3      38.1
# 50   11/17/2011     16:16   Thursday    Home     51.16     127.6      72.4
# 52   11/16/2011     16:13  Wednesday    Home     51.12     125.1      65.0
# 54   11/15/2011     17:36    Tuesday    Home     51.06     122.8      61.4
# 60    11/9/2011     16:15  Wednesday    Home     51.28     121.4      65.9
# 78   10/25/2011     17:24    Tuesday    Home     52.87     123.5      65.1
# 91   10/12/2011     17:47  Wednesday    Home     51.40     114.4      59.7
# 92   10/12/2011     08:28  Wednesday     GSK     50.58     128.4      59.5
# 110   9/27/2011     07:36    Tuesday     GSK     50.65     128.1      86.3
# 132    9/7/2011     07:57  Wednesday     GSK     49.08     125.1      56.5
# 133    9/6/2011     16:27    Tuesday    Home     52.88     131.6      95.4
# 150   8/24/2011     07:59  Wednesday     GSK     49.07     127.1      58.5
# 156   8/19/2011     07:05     Friday     GSK     49.18     123.0      72.0
# 158   8/18/2011     08:11   Thursday     GSK     52.26     137.7      51.2
# 165   8/12/2011     17:25     Friday    Home     55.57     127.7      69.6
# 166   8/12/2011     08:05     Friday     GSK     49.02     128.4      76.7
# 172    8/9/2011     08:15    Tuesday     GSK     49.08     134.8      60.5
# 174    8/8/2011     08:07     Monday     GSK     49.25     126.3      68.5
# 182    8/2/2011     07:38    Tuesday     GSK     53.48     124.9      68.8
# 184   7/29/2011     08:22     Friday     GSK     49.07     121.1      73.2
# 187   7/27/2011     17:24  Wednesday    Home     50.98     124.9      68.3
# 189   7/26/2011     17:15    Tuesday    Home     51.28     122.1      43.7
#
#      AvgMovingSpeed FuelEconomy  TotalTime  MovingTime Take407All  \
# 15             87.8        8.89       40.8        35.5         No
# 49             50.3       10.05       82.3        62.4         No
# 50             77.4       10.05       42.4        39.6         No
# 52             73.1        9.53       47.2        41.9         No
# 54             70.9        9.53       49.9        43.2         No
# 60             71.8        9.35       46.7        42.1         No
# 78             72.4        8.97       48.7        43.8         No
# 91             65.8        8.75       51.7        46.9         No
# 92             67.3        8.75       51.0        45.1        Yes
# 110            88.6        8.31       35.2        34.3        Yes
# 132            66.5         8.5       52.1        44.3         No
# 133            98.3         8.5       33.3        32.3        Yes
# 150            71.5        8.54       50.3        41.1         No
# 156            81.4        8.37       41.0        36.3         No
# 158            64.1        8.37       61.2        48.9         No
# 165            77.1        8.54       47.9        43.2         No
# 166            82.9        8.54       38.4        35.5         No
# 172            67.2        8.54       48.7        43.8         No
# 174            78.2        8.54       43.1        37.8         No
# 182            78.8        8.48       46.7        40.7         No
# 184            77.7        8.45       40.2        37.9         No
# 187            71.9        8.45       44.8        42.6         No
# 189            51.5        8.45       70.5        59.8         No
#
#                                            Comments
# 15                                Put snow tires on
# 49                              Huge traffic backup
# 50    Pumped tires up: check fuel economy improved?
# 52                              Backed up at Bronte
# 54                              Backed up at Bronte
# 60                                            Rainy
# 78                                 Rain, rain, rain
# 91                                 Rain, rain, rain
# 92       Accident: backup from Hamilton to 407 ramp
# 110                                         Raining
# 132                         Back to school traffic?
# 133              Took 407 all the way (to McMaster)
# 150                           Heavy volume on Derry
# 156                      Start early to run a batch
# 158  Accident at 403/highway 6; detour along Dundas
# 165                                    Detour taken
# 166                                  Must be Friday
# 172                           Medium amount of rain
# 174                                       New tires
# 182                            Turn around on Derry
# 184                                     Empty roads
# 187                          Police slowdown on 403
# 189                       Accident blocked 407 exit
#
# Dropping columns with missing values from the 2nd copy:
#           Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0     1/6/2012     16:37     Friday    Home     51.29     127.4      78.3
# 1     1/6/2012     08:20     Friday     GSK     51.63     130.3      81.8
# 2     1/4/2012     16:17  Wednesday    Home     51.27     127.4      82.0
# 3     1/4/2012     07:53  Wednesday     GSK     49.17     132.3      74.2
# 4     1/3/2012     18:57    Tuesday    Home     51.15     136.2      83.4
# ..         ...       ...        ...     ...       ...       ...       ...
# 200  7/18/2011     08:09     Monday     GSK     54.52     125.6      49.9
# 201  7/14/2011     08:03   Thursday     GSK     50.90     123.7      76.2
# 202  7/13/2011     17:08  Wednesday    Home     51.96     132.6      57.5
# 203  7/12/2011     17:51    Tuesday    Home     53.28     125.8      61.6
# 204  7/11/2011     16:56     Monday    Home     51.73     125.0      62.8
#
#      AvgMovingSpeed  TotalTime  MovingTime Take407All
# 0              84.8       39.3        36.3         No
# 1              88.9       37.9        34.9         No
# 2              85.8       37.5        35.9         No
# 3              82.9       39.8        35.6         No
# 4              88.1       36.8        34.8         No
# ..              ...        ...         ...        ...
# 200            82.4       65.5        39.7         No
# 201            95.1       40.1        32.1        Yes
# 202            76.7       54.2        40.6        Yes
# 203            87.6       51.9        36.5        Yes
# 204            92.5       49.5        33.6        Yes
#
# [205 rows x 11 columns]
#
# Getting summary statistics:
#          Distance    MaxSpeed    AvgSpeed  AvgMovingSpeed   TotalTime  \
# count  205.000000  205.000000  205.000000      205.000000  205.000000
# mean    50.981512  127.591707   74.477561       81.975610   41.904390
# std      1.321205    4.128450   11.409816       10.111544    6.849476
# min     48.320000  112.200000   38.100000       50.300000   28.200000
# 25%     50.650000  124.900000   68.900000       76.600000   38.400000
# 50%     51.140000  127.400000   73.600000       81.400000   41.300000
# 75%     51.630000  129.800000   79.900000       86.000000   44.400000
# max     60.320000  140.900000  107.700000      112.100000   82.300000
#
#        MovingTime
# count  205.000000
# mean    37.871707
# std      4.835072
# min     27.100000
# 25%     35.700000
# 50%     37.600000
# 75%     39.900000
# max     62.400000
#
# Viewing the correlation between the numerical columns:
#                 Distance  MaxSpeed  AvgSpeed  AvgMovingSpeed  TotalTime  \
# Distance        1.000000  0.145091 -0.006445        0.011874   0.197207
# MaxSpeed        0.145091  1.000000  0.253869        0.257823  -0.198775
# AvgSpeed       -0.006445  0.253869  1.000000        0.872143  -0.877806
# AvgMovingSpeed  0.011874  0.257823  0.872143        1.000000  -0.856986
# TotalTime       0.197207 -0.198775 -0.877806       -0.856986   1.000000
# MovingTime      0.197044 -0.222574 -0.835814       -0.944433   0.920935
#
#                 MovingTime
# Distance          0.197044
# MaxSpeed         -0.222574
# AvgSpeed         -0.835814
# AvgMovingSpeed   -0.944433
# TotalTime         0.920935
# MovingTime        1.000000
#
# Showing rows 11 to 14:
#           Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 11  12/21/2011     07:45  Wednesday     GSK     51.77     124.8      71.7
# 12  12/20/2011     16:05    Tuesday    Home     51.45     130.1      75.2
# 13  12/20/2011     06:04    Tuesday     GSK     49.01     119.0      77.4
# 14  12/19/2011     16:18     Monday    Home     51.04     132.2      77.5
#
#     AvgMovingSpeed FuelEconomy  TotalTime  MovingTime Take407All Comments
# 11            78.9        8.89       43.3        39.4         No      NaN
# 12            82.7        8.89       41.1        37.3         No      NaN
# 13            82.0        8.89       38.0        35.9         No      NaN
# 14            83.5        8.89       39.5        36.7         No      NaN
#
# Creating a subset with trips occurred on November 23, 2011 and January 6, 2012:
#           Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0     1/6/2012     16:37     Friday    Home     51.29     127.4      78.3
# 1     1/6/2012     08:20     Friday     GSK     51.63     130.3      81.8
# 44  11/23/2011     16:17  Wednesday    Home     60.32     129.4      68.9
# 45  11/23/2011     07:22  Wednesday     GSK     51.60     126.4      67.3
#
#     AvgMovingSpeed FuelEconomy  TotalTime  MovingTime Take407All Comments
# 0             84.8         NaN       39.3        36.3         No      NaN
# 1             88.9         NaN       37.9        34.9         No      NaN
# 44            74.6         9.3       52.5        48.5         No      NaN
# 45            73.6         9.3       46.0        42.1         No      NaN
#
# Producing plots for dataset:
